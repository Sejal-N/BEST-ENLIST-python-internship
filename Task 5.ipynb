# %% [markdown]
# EXERCISE :

# %% [markdown]
# 1) Create a function getting two integer inputs from user, and print the following :
#     a) Addition of two numbers is +value,
#     b) Subtraction of two numbers is +value,
#     c) Division of two numbers is +value,
#     d) Multiplication of two numbers is +value

# %%
Num1 = int(input("Enter First Number :"))
Num2 = int(input("Enter Second Number :"))
def arithmetic(Num1,Num2):
    print("Addition of two numbers is :",Num1 + Num2)
    print("Subtration of two numbers is :",Num1 - Num2)
    print("Division of two numbers is :",Num1 / Num2)
    print("Multiplication of two numbers is :",Num1 * Num2)
arithmetic(Num1,Num2)
# Out:
# Enter First Number : 9
# Enter Second Number : 3
# Addition of two numbers is : 12
# Subtration of two numbers is : 6
# Division of two numbers is : 3.0
# Multiplication of two numbers is : 27

# %% [markdown]
# 2) Create a function covid() & it should accept patient name, and body temperature by default the body temperature should be 98 degree.

# %%
name = input("Patient Name :")
temp = 98
def covid(name,temp):
    print("Patient's body temprature :",temp)
covid(name,temp=98)
# Out:
# Patient Name : Diksha
# Patient's body temprature : 98
