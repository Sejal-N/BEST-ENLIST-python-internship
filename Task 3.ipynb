# %% [markdown]
# EXERCISE :

# %% [markdown]
# 1) Write a python script to merge two python dictionaries.

# %%
d1 = {"w":"300","x":"100"}
d2 = {"y":"400","z":"200"}
d = d1.copy()
d.update(d2)
print(d)
# Out:
# {'w': '300', 'x': '100', 'y': '400', 'z': '200'}

# %% [markdown]
# 2) Write a python program to remove a key from a dictionary.

# %%
dit = {"a":"5","b":"10"}
print(dit)
if "a" in dit:
   del dit["a"]
print(dit)
# Out:
# {'a': '5', 'b': '10'}
# {'b': '10'}

# %% [markdown]
# 3) Write a python program to map two lists into a dictonary.

# %%
s1 = ["A","B","C","D"]
s2 = ["a","b","c","d"]
s = dict(zip(s1,s2))
print(s)
# Out:
# {'A': 'a', 'B': 'b', 'C': 'c', 'D': 'd'}

# %% [markdown]
# 4) Wrirte a program to find the lenght of a set

# %%
s1 = ["A","B","C","D"]
print(len(s1))
# Out:
# 4

# %% [markdown]
# 5) Write a python program to remove the intersection of a 2nd set from the 1st set

# %%
set_1 = {"red","blue","green"}
set_2 = {"orange","green","blacl"}
print(set_1-set_2)
# Out:
# {'blue', 'red'}
