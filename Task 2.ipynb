# %% [markdown]
# EXERCISE

# %% [markdown]
# 1) Create three variables (a,b,c) to same values of integer and do the following:
#      a) Divide a by 10
#      b) Multiply b by 50
#      c) Add c value by 60

# %%
a = b = c = 100
print(a/10)
print(b*50)
print(c+60)
# Out:
# 10.0
# 5000
# 160

# %% [markdown]
# 2) Create a string variable of 5 characters and replace the 3rd character with G.

# %%
str = "ARCUE"
str = str.replace("C","G")
print(str)
# Out:
# ARGUE

# %% [markdown]
# 3) Create two values (a,b) of int float data type and convert the vice versa, Hint : convert a from int to float datatype and b from float to int datatype

# %%
a,b = 78,5.8
print(float(a))
print(int(b))
# Out:
# 78.0
# 5
